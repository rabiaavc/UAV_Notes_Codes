# %%
# %ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 78A1-A073
#
#  Directory of c:\Users\HP\OneDrive\Masa�st�\PYTHON\Python_iha_odev_ve_notlar
#
# 22.11.2025  19:17    <DIR>          .
# 22.11.2025  19:17    <DIR>          ..
# 22.11.2025  19:18             8.545 dosya_ve_klasor_modulleri.ipynb
# 22.11.2025  19:17    <DIR>          �HA_�devler
#                1 File(s)          8.545 bytes
#                3 Dir(s)  202.655.432.704 bytes free

# %%
# %pwd #directory
# Out:
# 'c:\\Users\\HP\\OneDrive\\Masaüstü\\PYTHON\\Python_iha_odev_ve_notlar'

# %% [markdown]
# OS Modülü

# %% [markdown]
# Navigasyon ve İçerik Listeleme

# %%
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\HP\\OneDrive\\Masaüstü\\PYTHON\\Python_iha_odev_ve_notlar'

# %%
os.listdir()
# Out:
# ['dosya_ve_klasor_modulleri.ipynb', 'İHA_ödevler']

# %%
os.listdir('c:\\Users')
# Out:
# ['All Users', 'Default', 'Default User', 'desktop.ini', 'HP', 'Public']

# %%
os.chdir('c:\\Users')

# %%
os.getcwd()
# Out:
# 'c:\\Users'

# %%
os.chdir('c:\\Users\\HP\\OneDrive\\Masaüstü\\PYTHON\\Python_iha_odev_ve_notlar')

# %%
os.getcwd()
# Out:
# 'c:\\Users\\HP\\OneDrive\\Masaüstü\\PYTHON\\Python_iha_odev_ve_notlar'

# %%
dosyalar = os.listdir()

# %%
for eleman in dosyalar:
    print(eleman)
# Out:
# dosya_ve_klasor_modulleri.ipynb
# İHA_ödevler

# %% [markdown]
# Yeni Eleman Olusturma, İsim Degistirme ve Silme

# %% [markdown]
# Yeni klasör oluşturma

# %%
os.getcwd()
# Out:
# 'c:\\Users\\HP\\OneDrive\\Masaüstü\\PYTHON\\Python_iha_odev_ve_notlar'

# %%
os.mkdir('c:\\Users\\HP\\OneDrive\\Masaüstü\\PYTHON\\Python_iha_odev_ve_notlar\\deneme')

# %%
#Klasör silme
os.rmdir('c:\\Users\\HP\\OneDrive\\Masaüstü\\PYTHON\\Python_iha_odev_ve_notlar\\deneme')

# %%
os.listdir()
# Out:
# ['dosya_ve_klasor_modulleri.ipynb', 'İHA_ödevler']

# %% [markdown]
# Dosya Okuma ve Yazma İşlemleri

# %%
## os.O_RDONLY - Read Only
## os.O_WRDONLY - Write Only
## os.O_RDWR - Read and Write
## os.0_Creat -Create

# %%
yeni_dosya = os.open("yeni_dosya.txt",os.O_RDONLY | os.O_CREAT)
# os.write(yeni_dosya, "Merhaba Dünya !")

# %%
os.write(yeni_dosya, "Merhaba Dunya !".encode("utf-8"))
os.close(yeni_dosya)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 os.write(yeni_dosya, "Merhaba Dunya !".encode("utf-8"))
#       2 os.close(yeni_dosya)
#
# OSError: [Errno 9] Bad file descriptor

# %%
yeni_dosya = os.open("yeni_dosya.txt", os.O_RDONLY)
icerik = os.read(yeni_dosya, 5)
icerik
# Out:
# b''

# %%
# istatistik = os.stat(yeni_dosya)
# print(istatistik)

uzunluk = os.stat(yeni_dosya).st_size
print(icerik.decode())
os.close(yeni_dosya)

# %%
os.unlink("yeni_dosya.txt")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 os.unlink("yeni_dosya.txt")
#
# PermissionError: [WinError 32] Dosya başka bir işlem tarafından kullanıldığından bu işlem dosyaya erişemiyor: 'yeni_dosya.txt'

# %%
os.listdir()
# Out:
# ['dosya_ve_klasor_modulleri.ipynb', 'yeni_dosya.txt', 'İHA_ödevler']
